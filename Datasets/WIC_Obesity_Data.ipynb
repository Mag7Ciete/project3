# %%
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import datetime as dt
import json

# %%
import requests
import pandas as pd
import io
csv_url = "https://data.cdc.gov/api/views/735e-byxc/rows.csv"

# %%
# Download the CSV file
response = requests.get(csv_url)
content = response.content

# %%
df = pd.read_csv(io.StringIO(content.decode('utf-8')))

# %%
selected_columns = ['YearStart', 'LocationDesc','Data_Value','Sample_Size','Stratification1'] 
clean_df = df[selected_columns]
print (clean_df.head(5))
# Out:
#    YearStart   LocationDesc  Data_Value  Sample_Size Stratification1
# 0       2018     Washington        13.7      12230.0         18 - 23
# 1       2018         Hawaii        10.2       2192.0        Hispanic
# 2       2020  Massachusetts        17.6      13520.0        Hispanic
# 3       2020      Tennessee        18.9       4947.0        Hispanic
# 4       2012           Guam        12.0       1456.0            Male

# %%
clean_df = clean_df.rename(columns={'YearStart': "Year",'LocationDesc':'State','Stratification1':'Category'})

# %%
clean_df["Category"].unique()
# Out:
# array(['18 - 23', 'Hispanic', 'Male', 'Non-Hispanic White', '36 - 47',
#        'Female', 'Asian/Pacific Islander', 'Non-Hispanic Black',
#        '48 - 59', 'American Indian/Alaska Native', '6 - 11', '24 - 35',
#        '3 - 5', 'Total', '12 - 17'], dtype=object)

# %%
state_year_df = clean_df.groupby(["State", "Year"])["Data_Value"].mean()
print(state_year_df)
# Out:
# State    Year
# Alabama  2008    14.591176
#          2010    14.858824
#          2012    14.723529
#          2014    14.991176
#          2016    15.261765
#                    ...
# Wyoming  2012    12.051515
#          2014    10.233333
#          2016     9.970588
#          2018    10.970968
#          2020    11.358065
# Name: Data_Value, Length: 378, dtype: float64

# %%
state_year_df=state_year_df.reset_index()

# %%
state_year_list = []   
i=0 
for index,row in state_year_df.iterrows():
    entry = {}
    entry["State"] = row[0]
    entry["Year"] = row[1]
    entry["Data_Value"] = row[2]
    entry["ID"] = i
    i=i+1
    state_year_list.append(entry)

# %%
state_year_list
# Out:
# [{'State': 'Alabama', 'Year': 2008, 'Data_Value': 14.591176470588236, 'ID': 0},
#  {'State': 'Alabama', 'Year': 2010, 'Data_Value': 14.858823529411765, 'ID': 1},
#  {'State': 'Alabama', 'Year': 2012, 'Data_Value': 14.723529411764707, 'ID': 2},
#  {'State': 'Alabama', 'Year': 2014, 'Data_Value': 14.991176470588234, 'ID': 3},
#  {'State': 'Alabama', 'Year': 2016, 'Data_Value': 15.261764705882353, 'ID': 4},
#  {'State': 'Alabama', 'Year': 2018, 'Data_Value': 15.09705882352941, 'ID': 5},
#  {'State': 'Alabama', 'Year': 2020, 'Data_Value': 14.81764705882353, 'ID': 6},
#  {'State': 'Alaska', 'Year': 2008, 'Data_Value': 18.241176470588236, 'ID': 7},
#  {'State': 'Alaska', 'Year': 2010, 'Data_Value': 17.908823529411762, 'ID': 8},
#  {'State': 'Alaska', 'Year': 2012, 'Data_Value': 18.052941176470586, 'ID': 9},
#  {'State': 'Alaska', 'Year': 2014, 'Data_Value': 16.75294117647059, 'ID': 10},
#  {'State': 'Alaska', 'Year': 2016, 'Data_Value': 17.358823529411765, 'ID': 11},
#  {'State': 'Alaska', 'Year': 2018, 'Data_Value': 16.84705882352941, 'ID': 12},
#  {'State': 'Alaska', 'Year': 2020, 'Data_Value': 16.929411764705883, 'ID': 13},
#  {'State': 'Arizona',
#   'Year': 2008,
#   'Data_Value': 15.608823529411765,
#   'ID': 14},
#  {'State': 'Arizona',
#   'Year': 2010,
#   'Data_Value': 15.105882352941178,
#   'ID': 15},
#  {'State': 'Arizona',
#   'Year': 2012,
#   'Data_Value': 14.588235294117647,
#   'ID': 16},
#  {'State': 'Arizona',
#   'Year': 2014,
#   'Data_Value': 13.320588235294117,
#   'ID': 17},
#  {'State': 'Arizona',
#   'Year': 2016,
#   'Data_Value': 13.058823529411764,
#   'ID': 18},
#  {'State': 'Arizona',
#   'Year': 2018,
#   'Data_Value': 13.282352941176471,
#   'ID': 19},
#  {'State': 'Arizona', 'Year': 2020, 'Data_Value': 13.26764705882353, 'ID': 20},
#  {'State': 'Arkansas',
#   'Year': 2008,
#   'Data_Value': 12.805882352941175,
#   'ID': 21},
#  {'State': 'Arkansas',
#   'Year': 2010,
#   'Data_Value': 14.50294117647059,
#   'ID': 22},
#  {'State': 'Arkansas',
#   'Year': 2012,
#   'Data_Value': 13.611764705882353,
#   'ID': 23},
#  {'State': 'Arkansas',
#   'Year': 2014,
#   'Data_Value': 13.264705882352942,
#   'ID': 24},
#  {'State': 'Arkansas',
#   'Year': 2016,
#   'Data_Value': 12.873529411764705,
#   'ID': 25},
#  {'State': 'Arkansas',
#   'Year': 2018,
#   'Data_Value': 13.01764705882353,
#   'ID': 26},
#  {'State': 'Arkansas',
#   'Year': 2020,
#   'Data_Value': 13.282352941176471,
#   'ID': 27},
#  {'State': 'California',
#   'Year': 2008,
#   'Data_Value': 16.358823529411765,
#   'ID': 28},
#  {'State': 'California',
#   'Year': 2010,
#   'Data_Value': 16.561764705882354,
#   'ID': 29},
#  {'State': 'California',
#   'Year': 2012,
#   'Data_Value': 15.564705882352943,
#   'ID': 30},
#  {'State': 'California',
#   'Year': 2014,
#   'Data_Value': 14.329411764705881,
#   'ID': 31},
#  {'State': 'California',
#   'Year': 2016,
#   'Data_Value': 13.835294117647058,
#   'ID': 32},
#  {'State': 'California',
#   'Year': 2018,
#   'Data_Value': 13.935294117647059,
#   'ID': 33},
#  {'State': 'California',
#   'Year': 2020,
#   'Data_Value': 14.847058823529412,
#   'ID': 34},
#  {'State': 'Colorado',
#   'Year': 2008,
#   'Data_Value': 10.044117647058824,
#   'ID': 35},
#  {'State': 'Colorado',
#   'Year': 2010,
#   'Data_Value': 9.994117647058824,
#   'ID': 36},
#  {'State': 'Colorado',
#   'Year': 2012,
#   'Data_Value': 9.329411764705881,
#   'ID': 37},
#  {'State': 'Colorado',
#   'Year': 2014,
#   'Data_Value': 9.532352941176471,
#   'ID': 38},
#  {'State': 'Colorado',
#   'Year': 2016,
#   'Data_Value': 9.061764705882354,
#   'ID': 39},
#  {'State': 'Colorado',
#   'Year': 2018,
#   'Data_Value': 9.341176470588236,
#   'ID': 40},
#  {'State': 'Colorado',
#   'Year': 2020,
#   'Data_Value': 9.561764705882354,
#   'ID': 41},
#  {'State': 'Connecticut',
#   'Year': 2008,
#   'Data_Value': 14.51764705882353,
#   'ID': 42},
#  {'State': 'Connecticut',
#   'Year': 2010,
#   'Data_Value': 13.697058823529412,
#   'ID': 43},
#  {'State': 'Connecticut',
#   'Year': 2012,
#   'Data_Value': 13.397058823529411,
#   'ID': 44},
#  {'State': 'Connecticut',
#   'Year': 2014,
#   'Data_Value': 12.66764705882353,
#   'ID': 45},
#  {'State': 'Connecticut',
#   'Year': 2016,
#   'Data_Value': 12.287096774193548,
#   'ID': 46},
#  {'State': 'Connecticut',
#   'Year': 2018,
#   'Data_Value': 11.95483870967742,
#   'ID': 47},
#  {'State': 'Connecticut',
#   'Year': 2020,
#   'Data_Value': 12.006451612903225,
#   'ID': 48},
#  {'State': 'Delaware',
#   'Year': 2008,
#   'Data_Value': 15.329032258064515,
#   'ID': 49},
#  {'State': 'Delaware',
#   'Year': 2010,
#   'Data_Value': 15.748387096774193,
#   'ID': 50},
#  {'State': 'Delaware',
#   'Year': 2012,
#   'Data_Value': 15.780645161290321,
#   'ID': 51},
#  {'State': 'Delaware',
#   'Year': 2014,
#   'Data_Value': 14.903225806451612,
#   'ID': 52},
#  {'State': 'Delaware',
#   'Year': 2016,
#   'Data_Value': 14.851612903225806,
#   'ID': 53},
#  {'State': 'Delaware',
#   'Year': 2018,
#   'Data_Value': 15.067741935483872,
#   'ID': 54},
#  {'State': 'Delaware',
#   'Year': 2020,
#   'Data_Value': 16.15806451612903,
#   'ID': 55},
#  {'State': 'District of Columbia',
#   'Year': 2008,
#   'Data_Value': 14.02258064516129,
#   'ID': 56},
#  {'State': 'District of Columbia',
#   'Year': 2010,
#   'Data_Value': 14.116129032258064,
#   'ID': 57},
#  {'State': 'District of Columbia',
#   'Year': 2012,
#   'Data_Value': 13.45,
#   'ID': 58},
#  {'State': 'District of Columbia',
#   'Year': 2014,
#   'Data_Value': 12.603333333333333,
#   'ID': 59},
#  {'State': 'District of Columbia', 'Year': 2016, 'Data_Value': 11.5, 'ID': 60},
#  {'State': 'District of Columbia',
#   'Year': 2018,
#   'Data_Value': 12.810714285714285,
#   'ID': 61},
#  {'State': 'District of Columbia',
#   'Year': 2020,
#   'Data_Value': 12.368,
#   'ID': 62},
#  {'State': 'Florida',
#   'Year': 2008,
#   'Data_Value': 13.988235294117647,
#   'ID': 63},
#  {'State': 'Florida',
#   'Year': 2010,
#   'Data_Value': 13.708823529411765,
#   'ID': 64},
#  {'State': 'Florida',
#   'Year': 2012,
#   'Data_Value': 12.711764705882352,
#   'ID': 65},
#  {'State': 'Florida',
#   'Year': 2014,
#   'Data_Value': 12.085294117647058,
#   'ID': 66},
#  {'State': 'Florida',
#   'Year': 2016,
#   'Data_Value': 12.414705882352942,
#   'ID': 67},
#  {'State': 'Florida', 'Year': 2018, 'Data_Value': 12.5, 'ID': 68},
#  {'State': 'Florida', 'Year': 2020, 'Data_Value': 12.93235294117647, 'ID': 69},
#  {'State': 'Georgia',
#   'Year': 2008,
#   'Data_Value': 14.529411764705882,
#   'ID': 70},
#  {'State': 'Georgia',
#   'Year': 2010,
#   'Data_Value': 13.979411764705883,
#   'ID': 71},
#  {'State': 'Georgia',
#   'Year': 2012,
#   'Data_Value': 12.973529411764707,
#   'ID': 72},
#  {'State': 'Georgia',
#   'Year': 2014,
#   'Data_Value': 12.261764705882353,
#   'ID': 73},
#  {'State': 'Georgia',
#   'Year': 2016,
#   'Data_Value': 12.141176470588235,
#   'ID': 74},
#  {'State': 'Georgia',
#   'Year': 2018,
#   'Data_Value': 12.782352941176471,
#   'ID': 75},
#  {'State': 'Georgia',
#   'Year': 2020,
#   'Data_Value': 12.438235294117646,
#   'ID': 76},
#  {'State': 'Guam', 'Year': 2008, 'Data_Value': 11.78, 'ID': 77},
#  {'State': 'Guam', 'Year': 2010, 'Data_Value': 11.708, 'ID': 78},
#  {'State': 'Guam', 'Year': 2012, 'Data_Value': 10.621739130434783, 'ID': 79},
#  {'State': 'Guam', 'Year': 2014, 'Data_Value': 9.786363636363637, 'ID': 80},
#  {'State': 'Guam', 'Year': 2016, 'Data_Value': 10.736363636363636, 'ID': 81},
#  {'State': 'Guam', 'Year': 2018, 'Data_Value': 11.036363636363637, 'ID': 82},
#  {'State': 'Guam', 'Year': 2020, 'Data_Value': 10.990909090909092, 'ID': 83},
#  {'State': 'Hawaii', 'Year': 2008, 'Data_Value': 11.090909090909092, 'ID': 84},
#  {'State': 'Hawaii', 'Year': 2010, 'Data_Value': 10.588235294117647, 'ID': 85},
#  {'State': 'Hawaii', 'Year': 2012, 'Data_Value': 10.894117647058822, 'ID': 86},
#  {'State': 'Hawaii', 'Year': 2014, 'Data_Value': 10.861290322580645, 'ID': 87},
#  {'State': 'Hawaii', 'Year': 2016, 'Data_Value': 10.245161290322581, 'ID': 88},
#  {'State': 'Hawaii', 'Year': 2018, 'Data_Value': 11.120588235294118, 'ID': 89},
#  {'State': 'Hawaii', 'Year': 2020, 'Data_Value': 10.902941176470588, 'ID': 90},
#  {'State': 'Idaho', 'Year': 2008, 'Data_Value': 13.544117647058824, 'ID': 91},
#  {'State': 'Idaho', 'Year': 2010, 'Data_Value': 13.426470588235293, 'ID': 92},
#  {'State': 'Idaho', 'Year': 2012, 'Data_Value': 12.452941176470588, 'ID': 93},
#  {'State': 'Idaho', 'Year': 2014, 'Data_Value': 12.235294117647058, 'ID': 94},
#  {'State': 'Idaho', 'Year': 2016, 'Data_Value': 12.241176470588234, 'ID': 95},
#  {'State': 'Idaho', 'Year': 2018, 'Data_Value': 12.808823529411764, 'ID': 96},
#  {'State': 'Idaho', 'Year': 2020, 'Data_Value': 12.720588235294118, 'ID': 97},
#  {'State': 'Illinois',
#   'Year': 2008,
#   'Data_Value': 13.455882352941176,
#   'ID': 98},
#  {'State': 'Illinois',
#   'Year': 2010,
#   'Data_Value': 13.802941176470588,
#   'ID': 99},
#  {'State': 'Illinois',
#   'Year': 2012,
#   'Data_Value': 13.538235294117648,
#   'ID': 100},
#  {'State': 'Illinois',
#   'Year': 2014,
#   'Data_Value': 13.485294117647058,
#   'ID': 101},
#  {'State': 'Illinois', 'Year': 2016, 'Data_Value': 13.5, 'ID': 102},
#  {'State': 'Illinois',
#   'Year': 2018,
#   'Data_Value': 13.411764705882353,
#   'ID': 103},
#  {'State': 'Illinois', 'Year': 2020, 'Data_Value': 13.165625, 'ID': 104},
#  {'State': 'Indiana',
#   'Year': 2008,
#   'Data_Value': 14.467647058823529,
#   'ID': 105},
#  {'State': 'Indiana',
#   'Year': 2010,
#   'Data_Value': 14.564705882352941,
#   'ID': 106},
#  {'State': 'Indiana',
#   'Year': 2012,
#   'Data_Value': 14.13529411764706,
#   'ID': 107},
#  {'State': 'Indiana',
#   'Year': 2014,
#   'Data_Value': 13.23235294117647,
#   'ID': 108},
#  {'State': 'Indiana',
#   'Year': 2016,
#   'Data_Value': 12.714705882352941,
#   'ID': 109},
#  {'State': 'Indiana',
#   'Year': 2018,
#   'Data_Value': 13.229411764705883,
#   'ID': 110},
#  {'State': 'Indiana',
#   'Year': 2020,
#   'Data_Value': 12.785294117647059,
#   'ID': 111},
#  {'State': 'Iowa', 'Year': 2008, 'Data_Value': 15.6, 'ID': 112},
#  {'State': 'Iowa', 'Year': 2010, 'Data_Value': 15.623529411764707, 'ID': 113},
#  {'State': 'Iowa', 'Year': 2012, 'Data_Value': 14.852941176470589, 'ID': 114},
#  {'State': 'Iowa', 'Year': 2014, 'Data_Value': 15.020588235294117, 'ID': 115},
#  {'State': 'Iowa', 'Year': 2016, 'Data_Value': 15.488235294117647, 'ID': 116},
#  {'State': 'Iowa', 'Year': 2018, 'Data_Value': 15.75, 'ID': 117},
#  {'State': 'Iowa', 'Year': 2020, 'Data_Value': 15.6, 'ID': 118},
#  {'State': 'Kansas',
#   'Year': 2008,
#   'Data_Value': 14.461764705882352,
#   'ID': 119},
#  {'State': 'Kansas',
#   'Year': 2010,
#   'Data_Value': 14.288235294117648,
#   'ID': 120},
#  {'State': 'Kansas',
#   'Year': 2012,
#   'Data_Value': 13.370588235294118,
#   'ID': 121},
#  {'State': 'Kansas',
#   'Year': 2014,
#   'Data_Value': 13.058823529411764,
#   'ID': 122},
#  {'State': 'Kansas',
#   'Year': 2016,
#   'Data_Value': 12.685294117647059,
#   'ID': 123},
#  {'State': 'Kansas',
#   'Year': 2018,
#   'Data_Value': 13.491176470588234,
#   'ID': 124},
#  {'State': 'Kansas',
#   'Year': 2020,
#   'Data_Value': 12.785294117647059,
#   'ID': 125},
#  {'State': 'Kentucky',
#   'Year': 2008,
#   'Data_Value': 17.05757575757576,
#   'ID': 126},
#  {'State': 'Kentucky',
#   'Year': 2010,
#   'Data_Value': 17.96363636363636,
#   'ID': 127},
#  {'State': 'Kentucky',
#   'Year': 2012,
#   'Data_Value': 12.863636363636363,
#   'ID': 128},
#  {'State': 'Kentucky',
#   'Year': 2014,
#   'Data_Value': 12.414705882352942,
#   'ID': 129},
#  {'State': 'Kentucky',
#   'Year': 2016,
#   'Data_Value': 16.126470588235293,
#   'ID': 130},
#  {'State': 'Kentucky',
#   'Year': 2018,
#   'Data_Value': 15.720588235294118,
#   'ID': 131},
#  {'State': 'Kentucky',
#   'Year': 2020,
#   'Data_Value': 15.20909090909091,
#   'ID': 132},
#  {'State': 'Louisiana',
#   'Year': 2008,
#   'Data_Value': 16.50588235294118,
#   'ID': 133},
#  {'State': 'Louisiana',
#   'Year': 2010,
#   'Data_Value': 15.873529411764707,
#   'ID': 134},
#  {'State': 'Louisiana',
#   'Year': 2012,
#   'Data_Value': 15.049999999999999,
#   'ID': 135},
#  {'State': 'Louisiana',
#   'Year': 2014,
#   'Data_Value': 14.511764705882353,
#   'ID': 136},
#  {'State': 'Louisiana',
#   'Year': 2016,
#   'Data_Value': 14.652941176470588,
#   'ID': 137},
#  {'State': 'Louisiana',
#   'Year': 2018,
#   'Data_Value': 14.494117647058824,
#   'ID': 138},
#  {'State': 'Louisiana',
#   'Year': 2020,
#   'Data_Value': 14.064705882352941,
#   'ID': 139},
#  {'State': 'Maine', 'Year': 2008, 'Data_Value': 15.876470588235293, 'ID': 140},
#  {'State': 'Maine', 'Year': 2010, 'Data_Value': 14.964705882352941, 'ID': 141},
#  {'State': 'Maine', 'Year': 2012, 'Data_Value': 14.061764705882354, 'ID': 142},
#  {'State': 'Maine', 'Year': 2014, 'Data_Value': 13.644117647058822, 'ID': 143},
#  {'State': 'Maine', 'Year': 2016, 'Data_Value': 13.026470588235293, 'ID': 144},
#  {'State': 'Maine', 'Year': 2018, 'Data_Value': 13.967647058823529, 'ID': 145},
#  {'State': 'Maine', 'Year': 2020, 'Data_Value': 14.312121212121212, 'ID': 146},
#  {'State': 'Maryland',
#   'Year': 2008,
#   'Data_Value': 15.702941176470588,
#   'ID': 147},
#  {'State': 'Maryland', 'Year': 2010, 'Data_Value': 15.8, 'ID': 148},
#  {'State': 'Maryland',
#   'Year': 2012,
#   'Data_Value': 14.855882352941178,
#   'ID': 149},
#  {'State': 'Maryland',
#   'Year': 2014,
#   'Data_Value': 14.985294117647058,
#   'ID': 150},
#  {'State': 'Maryland',
#   'Year': 2016,
#   'Data_Value': 14.767647058823528,
#   'ID': 151},
#  {'State': 'Maryland',
#   'Year': 2018,
#   'Data_Value': 15.438235294117646,
#   'ID': 152},
#  {'State': 'Maryland',
#   'Year': 2020,
#   'Data_Value': 15.273529411764704,
#   'ID': 153},
#  {'State': 'Massachusetts',
#   'Year': 2008,
#   'Data_Value': 16.46060606060606,
#   'ID': 154},
#  {'State': 'Massachusetts',
#   'Year': 2010,
#   'Data_Value': 16.015151515151516,
#   'ID': 155},
#  {'State': 'Massachusetts',
#   'Year': 2012,
#   'Data_Value': 15.473529411764707,
#   'ID': 156},
#  {'State': 'Massachusetts',
#   'Year': 2014,
#   'Data_Value': 14.870588235294118,
#   'ID': 157},
#  {'State': 'Massachusetts', 'Year': 2016, 'Data_Value': 14.5, 'ID': 158},
#  {'State': 'Massachusetts',
#   'Year': 2018,
#   'Data_Value': 14.691176470588236,
#   'ID': 159},
#  {'State': 'Massachusetts', 'Year': 2020, 'Data_Value': 15.35, 'ID': 160},
#  {'State': 'Michigan',
#   'Year': 2008,
#   'Data_Value': 14.429411764705883,
#   'ID': 161},
#  {'State': 'Michigan',
#   'Year': 2010,
#   'Data_Value': 14.676470588235293,
#   'ID': 162},
#  {'State': 'Michigan',
#   'Year': 2012,
#   'Data_Value': 14.129411764705882,
#   'ID': 163},
#  {'State': 'Michigan',
#   'Year': 2014,
#   'Data_Value': 13.776470588235293,
#   'ID': 164},
#  {'State': 'Michigan',
#   'Year': 2016,
#   'Data_Value': 13.658823529411764,
#   'ID': 165},
#  {'State': 'Michigan',
#   'Year': 2018,
#   'Data_Value': 13.923529411764706,
#   'ID': 166},
#  {'State': 'Michigan',
#   'Year': 2020,
#   'Data_Value': 13.714705882352941,
#   'ID': 167},
#  {'State': 'Minnesota',
#   'Year': 2008,
#   'Data_Value': 14.74705882352941,
#   'ID': 168},
#  {'State': 'Minnesota',
#   'Year': 2010,
#   'Data_Value': 14.282352941176471,
#   'ID': 169},
#  {'State': 'Minnesota',
#   'Year': 2012,
#   'Data_Value': 13.988235294117647,
#   'ID': 170},
#  {'State': 'Minnesota', 'Year': 2014, 'Data_Value': 13.5, 'ID': 171},
#  {'State': 'Minnesota',
#   'Year': 2016,
#   'Data_Value': 13.767647058823528,
#   'ID': 172},
#  {'State': 'Minnesota',
#   'Year': 2018,
#   'Data_Value': 13.826470588235296,
#   'ID': 173},
#  {'State': 'Minnesota',
#   'Year': 2020,
#   'Data_Value': 13.68235294117647,
#   'ID': 174},
#  {'State': 'Mississippi',
#   'Year': 2008,
#   'Data_Value': 16.638709677419353,
#   'ID': 175},
#  {'State': 'Mississippi',
#   'Year': 2010,
#   'Data_Value': 16.25294117647059,
#   'ID': 176},
#  {'State': 'Mississippi',
#   'Year': 2012,
#   'Data_Value': 15.744117647058822,
#   'ID': 177},
#  {'State': 'Mississippi',
#   'Year': 2014,
#   'Data_Value': 14.890322580645162,
#   'ID': 178},
#  {'State': 'Mississippi',
#   'Year': 2016,
#   'Data_Value': 14.27741935483871,
#   'ID': 179},
#  {'State': 'Mississippi',
#   'Year': 2018,
#   'Data_Value': 13.612903225806452,
#   'ID': 180},
#  {'State': 'Mississippi',
#   'Year': 2020,
#   'Data_Value': 13.651612903225805,
#   'ID': 181},
#  {'State': 'Missouri',
#   'Year': 2008,
#   'Data_Value': 15.444117647058825,
#   'ID': 182},
#  {'State': 'Missouri',
#   'Year': 2010,
#   'Data_Value': 14.402941176470588,
#   'ID': 183},
#  {'State': 'Missouri',
#   'Year': 2012,
#   'Data_Value': 12.979411764705883,
#   'ID': 184},
#  {'State': 'Missouri', 'Year': 2014, 'Data_Value': 12.85, 'ID': 185},
#  {'State': 'Missouri',
#   'Year': 2016,
#   'Data_Value': 12.620588235294118,
#   'ID': 186},
#  {'State': 'Missouri',
#   'Year': 2018,
#   'Data_Value': 12.402941176470588,
#   'ID': 187},
#  {'State': 'Missouri', 'Year': 2020, 'Data_Value': 13.1, 'ID': 188},
#  {'State': 'Montana',
#   'Year': 2008,
#   'Data_Value': 13.688235294117648,
#   'ID': 189},
#  {'State': 'Montana',
#   'Year': 2010,
#   'Data_Value': 12.458823529411765,
#   'ID': 190},
#  {'State': 'Montana',
#   'Year': 2012,
#   'Data_Value': 12.029411764705882,
#   'ID': 191},
#  {'State': 'Montana',
#   'Year': 2014,
#   'Data_Value': 12.155882352941177,
#   'ID': 192},
#  {'State': 'Montana',
#   'Year': 2016,
#   'Data_Value': 11.41764705882353,
#   'ID': 193},
#  {'State': 'Montana',
#   'Year': 2018,
#   'Data_Value': 11.835294117647058,
#   'ID': 194},
#  {'State': 'Montana',
#   'Year': 2020,
#   'Data_Value': 11.883870967741935,
#   'ID': 195},
#  {'State': 'Nebraska',
#   'Year': 2008,
#   'Data_Value': 15.020588235294117,
#   'ID': 196},
#  {'State': 'Nebraska',
#   'Year': 2010,
#   'Data_Value': 14.967647058823529,
#   'ID': 197},
#  {'State': 'Nebraska',
#   'Year': 2012,
#   'Data_Value': 16.370588235294118,
#   'ID': 198},
#  {'State': 'Nebraska',
#   'Year': 2014,
#   'Data_Value': 16.49705882352941,
#   'ID': 199},
#  {'State': 'Nebraska',
#   'Year': 2016,
#   'Data_Value': 14.558823529411764,
#   'ID': 200},
#  {'State': 'Nebraska',
#   'Year': 2018,
#   'Data_Value': 14.294117647058824,
#   'ID': 201},
#  {'State': 'Nebraska',
#   'Year': 2020,
#   'Data_Value': 13.688235294117646,
#   'ID': 202},
#  {'State': 'Nevada',
#   'Year': 2008,
#   'Data_Value': 13.273529411764706,
#   'ID': 203},
#  {'State': 'Nevada',
#   'Year': 2010,
#   'Data_Value': 13.614705882352942,
#   'ID': 204},
#  {'State': 'Nevada',
#   'Year': 2012,
#   'Data_Value': 12.688235294117646,
#   'ID': 205},
#  {'State': 'Nevada',
#   'Year': 2014,
#   'Data_Value': 12.797058823529412,
#   'ID': 206},
#  {'State': 'Nevada',
#   'Year': 2016,
#   'Data_Value': 12.452941176470588,
#   'ID': 207},
#  {'State': 'Nevada', 'Year': 2018, 'Data_Value': 12.38529411764706, 'ID': 208},
#  {'State': 'Nevada', 'Year': 2020, 'Data_Value': 11.63529411764706, 'ID': 209},
#  {'State': 'New Hampshire', 'Year': 2008, 'Data_Value': 15.90625, 'ID': 210},
#  {'State': 'New Hampshire',
#   'Year': 2010,
#   'Data_Value': 15.28529411764706,
#   'ID': 211},
#  {'State': 'New Hampshire',
#   'Year': 2012,
#   'Data_Value': 14.245454545454546,
#   'ID': 212},
#  {'State': 'New Hampshire',
#   'Year': 2014,
#   'Data_Value': 14.583870967741936,
#   'ID': 213},
#  {'State': 'New Hampshire',
#   'Year': 2016,
#   'Data_Value': 15.296774193548387,
#   'ID': 214},
#  {'State': 'New Hampshire',
#   'Year': 2018,
#   'Data_Value': 15.519354838709678,
#   'ID': 215},
#  {'State': 'New Hampshire',
#   'Year': 2020,
#   'Data_Value': 15.561290322580644,
#   'ID': 216},
#  {'State': 'New Jersey',
#   'Year': 2008,
#   'Data_Value': 16.811764705882354,
#   'ID': 217},
#  {'State': 'New Jersey',
#   'Year': 2010,
#   'Data_Value': 16.379411764705882,
#   'ID': 218},
#  {'State': 'New Jersey',
#   'Year': 2012,
#   'Data_Value': 15.126470588235293,
#   'ID': 219},
#  {'State': 'New Jersey',
#   'Year': 2014,
#   'Data_Value': 13.973529411764707,
#   'ID': 220},
#  {'State': 'New Jersey',
#   'Year': 2016,
#   'Data_Value': 13.299999999999999,
#   'ID': 221},
#  {'State': 'New Jersey',
#   'Year': 2018,
#   'Data_Value': 13.302941176470588,
#   'ID': 222},
#  {'State': 'New Jersey',
#   'Year': 2020,
#   'Data_Value': 13.773529411764706,
#   'ID': 223},
#  {'State': 'New Mexico',
#   'Year': 2008,
#   'Data_Value': 12.520588235294117,
#   'ID': 224},
#  {'State': 'New Mexico',
#   'Year': 2010,
#   'Data_Value': 14.81764705882353,
#   'ID': 225},
#  {'State': 'New Mexico',
#   'Year': 2012,
#   'Data_Value': 13.052941176470588,
#   'ID': 226},
#  {'State': 'New Mexico',
#   'Year': 2014,
#   'Data_Value': 12.105882352941178,
#   'ID': 227},
#  {'State': 'New Mexico',
#   'Year': 2016,
#   'Data_Value': 11.799999999999999,
#   'ID': 228},
#  {'State': 'New Mexico',
#   'Year': 2018,
#   'Data_Value': 12.529411764705882,
#   'ID': 229},
#  {'State': 'New Mexico',
#   'Year': 2020,
#   'Data_Value': 11.402941176470588,
#   'ID': 230},
#  {'State': 'New York',
#   'Year': 2008,
#   'Data_Value': 15.117647058823529,
#   'ID': 231},
#  {'State': 'New York',
#   'Year': 2010,
#   'Data_Value': 15.13529411764706,
#   'ID': 232},
#  {'State': 'New York',
#   'Year': 2012,
#   'Data_Value': 13.876470588235295,
#   'ID': 233},
#  {'State': 'New York',
#   'Year': 2014,
#   'Data_Value': 13.202941176470588,
#   'ID': 234},
#  {'State': 'New York',
#   'Year': 2016,
#   'Data_Value': 12.705882352941176,
#   'ID': 235},
#  {'State': 'New York',
#   'Year': 2018,
#   'Data_Value': 12.773529411764706,
#   'ID': 236},
#  {'State': 'New York',
#   'Year': 2020,
#   'Data_Value': 12.670588235294119,
#   'ID': 237},
#  {'State': 'North Carolina',
#   'Year': 2008,
#   'Data_Value': 13.438235294117646,
#   'ID': 238},
#  {'State': 'North Carolina',
#   'Year': 2010,
#   'Data_Value': 13.282352941176471,
#   'ID': 239},
#  {'State': 'North Carolina',
#   'Year': 2012,
#   'Data_Value': 12.488235294117647,
#   'ID': 240},
#  {'State': 'North Carolina',
#   'Year': 2014,
#   'Data_Value': 14.061764705882354,
#   'ID': 241},
#  {'State': 'North Carolina',
#   'Year': 2016,
#   'Data_Value': 13.870588235294118,
#   'ID': 242},
#  {'State': 'North Carolina',
#   'Year': 2018,
#   'Data_Value': 14.023529411764706,
#   'ID': 243},
#  {'State': 'North Carolina',
#   'Year': 2020,
#   'Data_Value': 13.479411764705883,
#   'ID': 244},
#  {'State': 'North Dakota',
#   'Year': 2008,
#   'Data_Value': 15.458823529411765,
#   'ID': 245},
#  {'State': 'North Dakota',
#   'Year': 2010,
#   'Data_Value': 14.329411764705881,
#   'ID': 246},
#  {'State': 'North Dakota',
#   'Year': 2012,
#   'Data_Value': 14.220588235294118,
#   'ID': 247},
#  {'State': 'North Dakota',
#   'Year': 2014,
#   'Data_Value': 13.808823529411764,
#   'ID': 248},
#  {'State': 'North Dakota',
#   'Year': 2016,
#   'Data_Value': 14.570588235294117,
#   'ID': 249},
#  {'State': 'North Dakota',
#   'Year': 2018,
#   'Data_Value': 15.391176470588235,
#   'ID': 250},
#  {'State': 'North Dakota',
#   'Year': 2020,
#   'Data_Value': 15.632352941176471,
#   'ID': 251},
#  {'State': 'Ohio', 'Year': 2008, 'Data_Value': 13.541176470588235, 'ID': 252},
#  {'State': 'Ohio', 'Year': 2010, 'Data_Value': 13.870588235294118, 'ID': 253},
#  {'State': 'Ohio', 'Year': 2012, 'Data_Value': 13.588235294117647, 'ID': 254},
#  {'State': 'Ohio', 'Year': 2014, 'Data_Value': 13.520588235294117, 'ID': 255},
#  {'State': 'Ohio', 'Year': 2016, 'Data_Value': 13.276470588235293, 'ID': 256},
#  {'State': 'Ohio', 'Year': 2018, 'Data_Value': 13.049999999999999, 'ID': 257},
#  {'State': 'Ohio', 'Year': 2020, 'Data_Value': 12.897058823529411, 'ID': 258},
#  {'State': 'Oklahoma',
#   'Year': 2008,
#   'Data_Value': 14.664705882352942,
#   'ID': 259},
#  {'State': 'Oklahoma',
#   'Year': 2010,
#   'Data_Value': 14.826470588235296,
#   'ID': 260},
#  {'State': 'Oklahoma',
#   'Year': 2012,
#   'Data_Value': 14.173529411764704,
#   'ID': 261},
#  {'State': 'Oklahoma',
#   'Year': 2014,
#   'Data_Value': 12.86470588235294,
#   'ID': 262},
#  {'State': 'Oklahoma',
#   'Year': 2016,
#   'Data_Value': 12.826470588235296,
#   'ID': 263},
#  {'State': 'Oklahoma',
#   'Year': 2018,
#   'Data_Value': 13.255882352941176,
#   'ID': 264},
#  {'State': 'Oklahoma',
#   'Year': 2020,
#   'Data_Value': 12.720588235294118,
#   'ID': 265},
#  {'State': 'Oregon',
#   'Year': 2008,
#   'Data_Value': 14.738235294117647,
#   'ID': 266},
#  {'State': 'Oregon',
#   'Year': 2010,
#   'Data_Value': 14.788235294117648,
#   'ID': 267},
#  {'State': 'Oregon',
#   'Year': 2012,
#   'Data_Value': 15.070588235294117,
#   'ID': 268},
#  {'State': 'Oregon',
#   'Year': 2014,
#   'Data_Value': 14.473529411764707,
#   'ID': 269},
#  {'State': 'Oregon',
#   'Year': 2016,
#   'Data_Value': 14.055882352941175,
#   'ID': 270},
#  {'State': 'Oregon',
#   'Year': 2018,
#   'Data_Value': 14.011764705882353,
#   'ID': 271},
#  {'State': 'Oregon',
#   'Year': 2020,
#   'Data_Value': 14.020588235294117,
#   'ID': 272},
#  {'State': 'Pennsylvania',
#   'Year': 2008,
#   'Data_Value': 12.320588235294117,
#   'ID': 273},
#  {'State': 'Pennsylvania',
#   'Year': 2010,
#   'Data_Value': 13.561764705882354,
#   'ID': 274},
#  {'State': 'Pennsylvania',
#   'Year': 2012,
#   'Data_Value': 13.367647058823529,
#   'ID': 275},
#  {'State': 'Pennsylvania',
#   'Year': 2014,
#   'Data_Value': 12.911764705882353,
#   'ID': 276},
#  {'State': 'Pennsylvania',
#   'Year': 2016,
#   'Data_Value': 12.702941176470588,
#   'ID': 277},
#  {'State': 'Pennsylvania',
#   'Year': 2018,
#   'Data_Value': 13.138235294117647,
#   'ID': 278},
#  {'State': 'Pennsylvania',
#   'Year': 2020,
#   'Data_Value': 12.950000000000001,
#   'ID': 279},
#  {'State': 'Puerto Rico', 'Year': 2008, 'Data_Value': 18.2, 'ID': 280},
#  {'State': 'Puerto Rico', 'Year': 2010, 'Data_Value': 18.016, 'ID': 281},
#  {'State': 'Puerto Rico', 'Year': 2012, 'Data_Value': 12.74, 'ID': 282},
#  {'State': 'Puerto Rico', 'Year': 2014, 'Data_Value': 11.772, 'ID': 283},
#  {'State': 'Puerto Rico', 'Year': 2016, 'Data_Value': 10.636, 'ID': 284},
#  {'State': 'Puerto Rico',
#   'Year': 2018,
#   'Data_Value': 10.616666666666667,
#   'ID': 285},
#  {'State': 'Puerto Rico',
#   'Year': 2020,
#   'Data_Value': 10.703846153846154,
#   'ID': 286},
#  {'State': 'Rhode Island',
#   'Year': 2008,
#   'Data_Value': 16.454545454545453,
#   'ID': 287},
#  {'State': 'Rhode Island',
#   'Year': 2010,
#   'Data_Value': 15.524242424242424,
#   'ID': 288},
#  {'State': 'Rhode Island',
#   'Year': 2012,
#   'Data_Value': 14.954545454545455,
#   'ID': 289},
#  {'State': 'Rhode Island',
#   'Year': 2014,
#   'Data_Value': 14.66969696969697,
#   'ID': 290},
#  {'State': 'Rhode Island',
#   'Year': 2016,
#   'Data_Value': 14.394117647058822,
#   'ID': 291},
#  {'State': 'Rhode Island',
#   'Year': 2018,
#   'Data_Value': 15.338709677419354,
#   'ID': 292},
#  {'State': 'Rhode Island',
#   'Year': 2020,
#   'Data_Value': 15.167741935483871,
#   'ID': 293},
#  {'State': 'South Carolina',
#   'Year': 2008,
#   'Data_Value': 14.632352941176471,
#   'ID': 294},
#  {'State': 'South Carolina',
#   'Year': 2010,
#   'Data_Value': 13.705882352941176,
#   'ID': 295},
#  {'State': 'South Carolina',
#   'Year': 2012,
#   'Data_Value': 13.079411764705881,
#   'ID': 296},
#  {'State': 'South Carolina',
#   'Year': 2014,
#   'Data_Value': 12.305882352941175,
#   'ID': 297},
#  {'State': 'South Carolina',
#   'Year': 2016,
#   'Data_Value': 11.197058823529412,
#   'ID': 298},
#  {'State': 'South Carolina',
#   'Year': 2018,
#   'Data_Value': 11.579411764705881,
#   'ID': 299},
#  {'State': 'South Carolina',
#   'Year': 2020,
#   'Data_Value': 12.223529411764707,
#   'ID': 300},
#  {'State': 'South Dakota',
#   'Year': 2008,
#   'Data_Value': 16.941176470588236,
#   'ID': 301},
#  {'State': 'South Dakota',
#   'Year': 2010,
#   'Data_Value': 17.011764705882353,
#   'ID': 302},
#  {'State': 'South Dakota',
#   'Year': 2012,
#   'Data_Value': 14.988235294117647,
#   'ID': 303},
#  {'State': 'South Dakota',
#   'Year': 2014,
#   'Data_Value': 16.61470588235294,
#   'ID': 304},
#  {'State': 'South Dakota',
#   'Year': 2016,
#   'Data_Value': 17.629411764705882,
#   'ID': 305},
#  {'State': 'South Dakota',
#   'Year': 2018,
#   'Data_Value': 14.947058823529412,
#   'ID': 306},
#  {'State': 'South Dakota',
#   'Year': 2020,
#   'Data_Value': 15.397058823529411,
#   'ID': 307},
#  {'State': 'Tennessee',
#   'Year': 2008,
#   'Data_Value': 14.338709677419354,
#   'ID': 308},
#  {'State': 'Tennessee',
#   'Year': 2010,
#   'Data_Value': 15.116129032258065,
#   'ID': 309},
#  {'State': 'Tennessee',
#   'Year': 2012,
#   'Data_Value': 13.983870967741936,
#   'ID': 310},
#  {'State': 'Tennessee',
#   'Year': 2014,
#   'Data_Value': 13.929411764705883,
#   'ID': 311},
#  {'State': 'Tennessee', 'Year': 2016, 'Data_Value': 14.0, 'ID': 312},
#  {'State': 'Tennessee',
#   'Year': 2018,
#   'Data_Value': 14.078787878787878,
#   'ID': 313},
#  {'State': 'Tennessee',
#   'Year': 2020,
#   'Data_Value': 13.880645161290323,
#   'ID': 314},
#  {'State': 'Texas', 'Year': 2008, 'Data_Value': 15.841176470588236, 'ID': 315},
#  {'State': 'Texas', 'Year': 2010, 'Data_Value': 15.270588235294118, 'ID': 316},
#  {'State': 'Texas', 'Year': 2012, 'Data_Value': 14.464705882352941, 'ID': 317},
#  {'State': 'Texas', 'Year': 2014, 'Data_Value': 14.041176470588235, 'ID': 318},
#  {'State': 'Texas', 'Year': 2016, 'Data_Value': 14.073529411764707, 'ID': 319},
#  {'State': 'Texas', 'Year': 2018, 'Data_Value': 14.447058823529412, 'ID': 320},
#  {'State': 'Texas', 'Year': 2020, 'Data_Value': 14.652941176470588, 'ID': 321},
#  {'State': 'Utah', 'Year': 2008, 'Data_Value': 15.270588235294118, 'ID': 322},
#  {'State': 'Utah', 'Year': 2010, 'Data_Value': 14.429411764705883, 'ID': 323},
#  {'State': 'Utah', 'Year': 2012, 'Data_Value': 9.823529411764707, 'ID': 324},
#  {'State': 'Utah', 'Year': 2014, 'Data_Value': 9.870588235294118, 'ID': 325},
#  {'State': 'Utah', 'Year': 2016, 'Data_Value': 9.894117647058822, 'ID': 326},
#  {'State': 'Utah', 'Year': 2018, 'Data_Value': 9.879411764705882, 'ID': 327},
#  {'State': 'Utah', 'Year': 2020, 'Data_Value': 9.770588235294117, 'ID': 328},
#  {'State': 'Vermont', 'Year': 2008, 'Data_Value': 12.890625, 'ID': 329},
#  {'State': 'Vermont',
#   'Year': 2010,
#   'Data_Value': 12.812903225806451,
#   'ID': 330},
#  {'State': 'Vermont',
#   'Year': 2012,
#   'Data_Value': 12.36969696969697,
#   'ID': 331},
#  {'State': 'Vermont',
#   'Year': 2014,
#   'Data_Value': 13.418181818181818,
#   'ID': 332},
#  {'State': 'Vermont',
#   'Year': 2016,
#   'Data_Value': 14.272727272727273,
#   'ID': 333},
#  {'State': 'Vermont',
#   'Year': 2018,
#   'Data_Value': 13.366666666666667,
#   'ID': 334},
#  {'State': 'Vermont',
#   'Year': 2020,
#   'Data_Value': 13.190322580645162,
#   'ID': 335},
#  {'State': 'Virgin Islands',
#   'Year': 2008,
#   'Data_Value': 14.079166666666667,
#   'ID': 336},
#  {'State': 'Virgin Islands',
#   'Year': 2010,
#   'Data_Value': 12.183333333333332,
#   'ID': 337},
#  {'State': 'Virgin Islands', 'Year': 2012, 'Data_Value': 12.0625, 'ID': 338},
#  {'State': 'Virgin Islands', 'Year': 2014, 'Data_Value': 11.4, 'ID': 339},
#  {'State': 'Virgin Islands',
#   'Year': 2016,
#   'Data_Value': 12.834782608695651,
#   'ID': 340},
#  {'State': 'Virgin Islands',
#   'Year': 2018,
#   'Data_Value': 15.508333333333333,
#   'ID': 341},
#  {'State': 'Virgin Islands',
#   'Year': 2020,
#   'Data_Value': 12.869565217391305,
#   'ID': 342},
#  {'State': 'Virginia',
#   'Year': 2008,
#   'Data_Value': 21.461764705882356,
#   'ID': 343},
#  {'State': 'Virginia',
#   'Year': 2010,
#   'Data_Value': 21.72941176470588,
#   'ID': 344},
#  {'State': 'Virginia',
#   'Year': 2012,
#   'Data_Value': 20.926470588235293,
#   'ID': 345},
#  {'State': 'Virginia',
#   'Year': 2014,
#   'Data_Value': 20.51764705882353,
#   'ID': 346},
#  {'State': 'Virginia',
#   'Year': 2016,
#   'Data_Value': 14.726470588235294,
#   'ID': 347},
#  {'State': 'Virginia',
#   'Year': 2018,
#   'Data_Value': 15.041176470588235,
#   'ID': 348},
#  {'State': 'Virginia',
#   'Year': 2020,
#   'Data_Value': 14.626470588235295,
#   'ID': 349},
#  {'State': 'Washington',
#   'Year': 2008,
#   'Data_Value': 15.797058823529412,
#   'ID': 350},
#  {'State': 'Washington',
#   'Year': 2010,
#   'Data_Value': 15.394117647058822,
#   'ID': 351},
#  {'State': 'Washington',
#   'Year': 2012,
#   'Data_Value': 14.935294117647059,
#   'ID': 352},
#  {'State': 'Washington',
#   'Year': 2014,
#   'Data_Value': 14.052941176470588,
#   'ID': 353},
#  {'State': 'Washington',
#   'Year': 2016,
#   'Data_Value': 14.020588235294117,
#   'ID': 354},
#  {'State': 'Washington',
#   'Year': 2018,
#   'Data_Value': 14.338235294117647,
#   'ID': 355},
#  {'State': 'Washington',
#   'Year': 2020,
#   'Data_Value': 15.044117647058824,
#   'ID': 356},
#  {'State': 'West Virginia',
#   'Year': 2008,
#   'Data_Value': 13.108823529411765,
#   'ID': 357},
#  {'State': 'West Virginia',
#   'Year': 2010,
#   'Data_Value': 12.48235294117647,
#   'ID': 358},
#  {'State': 'West Virginia',
#   'Year': 2012,
#   'Data_Value': 12.584848484848486,
#   'ID': 359},
#  {'State': 'West Virginia',
#   'Year': 2014,
#   'Data_Value': 14.181818181818182,
#   'ID': 360},
#  {'State': 'West Virginia',
#   'Year': 2016,
#   'Data_Value': 14.60909090909091,
#   'ID': 361},
#  {'State': 'West Virginia',
#   'Year': 2018,
#   'Data_Value': 14.224242424242423,
#   'ID': 362},
#  {'State': 'West Virginia',
#   'Year': 2020,
#   'Data_Value': 14.906666666666666,
#   'ID': 363},
#  {'State': 'Wisconsin',
#   'Year': 2008,
#   'Data_Value': 15.670588235294117,
#   'ID': 364},
#  {'State': 'Wisconsin',
#   'Year': 2010,
#   'Data_Value': 16.429411764705883,
#   'ID': 365},
#  {'State': 'Wisconsin',
#   'Year': 2012,
#   'Data_Value': 15.926470588235293,
#   'ID': 366},
#  {'State': 'Wisconsin',
#   'Year': 2014,
#   'Data_Value': 15.50294117647059,
#   'ID': 367},
#  {'State': 'Wisconsin',
#   'Year': 2016,
#   'Data_Value': 15.273529411764704,
#   'ID': 368},
#  {'State': 'Wisconsin',
#   'Year': 2018,
#   'Data_Value': 15.305882352941175,
#   'ID': 369},
#  {'State': 'Wisconsin',
#   'Year': 2020,
#   'Data_Value': 15.673529411764704,
#   'ID': 370},
#  {'State': 'Wyoming', 'Year': 2008, 'Data_Value': 11.171875, 'ID': 371},
#  {'State': 'Wyoming',
#   'Year': 2010,
#   'Data_Value': 13.10909090909091,
#   'ID': 372},
#  {'State': 'Wyoming',
#   'Year': 2012,
#   'Data_Value': 12.05151515151515,
#   'ID': 373},
#  {'State': 'Wyoming',
#   'Year': 2014,
#   'Data_Value': 10.233333333333333,
#   'ID': 374},
#  {'State': 'Wyoming',
#   'Year': 2016,
#   'Data_Value': 9.970588235294118,
#   'ID': 375},
#  {'State': 'Wyoming',
#   'Year': 2018,
#   'Data_Value': 10.970967741935485,
#   'ID': 376},
#  {'State': 'Wyoming',
#   'Year': 2020,
#   'Data_Value': 11.358064516129033,
#   'ID': 377}]

# %%
Category_df = clean_df.sort_values(['Category']).drop_duplicates(subset=['State','Year'], keep='first')     
print (Category_df.head())
# Out:
#       Year          State  Data_Value  Sample_Size Category
# 6425  2016       New York        10.8      82012.0  12 - 17
# 5576  2008        Vermont        11.4       1378.0  12 - 17
# 5619  2012  New Hampshire        13.3       1524.0  12 - 17
# 5784  2014       Illinois        12.3      27575.0  12 - 17
# 5812  2012        Indiana        12.4      17041.0  12 - 17

# %%
Category_df = clean_df.sort_values(['Category']).drop_duplicates(subset=['Category'], keep='first')
Category_df = Category_df.reset_index(drop=True)
Category_df = Category_df.drop(columns=['Sample_Size'])
Category_df = Category_df.rename(columns={'Category': "ID",'Stratification1':'Category'})
Category_df = Category_df.reset_index(drop=True)
Category_df
# Out:
#     Year                 State  Data_Value                             ID
# 0   2016              New York        10.8                        12 - 17
# 1   2018             Louisiana        16.3                        18 - 23
# 2   2008               Vermont        12.5                        24 - 35
# 3   2012                  Ohio         9.0                          3 - 5
# 4   2018              Michigan        16.1                        36 - 47
# 5   2020              Illinois        16.7                        48 - 59
# 6   2010          Pennsylvania        12.6                         6 - 11
# 7   2010               Wyoming        18.1  American Indian/Alaska Native
# 8   2010                  Ohio        10.6         Asian/Pacific Islander
# 9   2020                  Ohio        15.2                         Female
# 10  2014  District of Columbia        20.0                       Hispanic
# 11  2012              Illinois        12.1                           Male
# 12  2016                 Maine         9.6             Non-Hispanic Black
# 13  2010              Oklahoma        11.9             Non-Hispanic White
# 14  2018           Puerto Rico        12.6                          Total

# %%
#Category_df['Category'].plot(kind='bar', figsize=(20,10))

# %%
#rouped_df = clean_df.groupby('State').median()
#print (grouped_df.head(20))

# %%
#state_year_df.plot(x='Satate', y='Year', rot=90,)
#state_year_df.plot(x='Satate', figsize=(20,10))
#plt.show()

# %%
state_year_df.to_csv('state_year_df.csv', index=True, header=True)

# %%
json.dumps(state_year_list)
# Out:
# '[{"State": "Alabama", "Year": 2008, "Data_Value": 14.591176470588236, "ID": 0}, {"State": "Alabama", "Year": 2010, "Data_Value": 14.858823529411765, "ID": 1}, {"State": "Alabama", "Year": 2012, "Data_Value": 14.723529411764707, "ID": 2}, {"State": "Alabama", "Year": 2014, "Data_Value": 14.991176470588234, "ID": 3}, {"State": "Alabama", "Year": 2016, "Data_Value": 15.261764705882353, "ID": 4}, {"State": "Alabama", "Year": 2018, "Data_Value": 15.09705882352941, "ID": 5}, {"State": "Alabama", "Year": 2020, "Data_Value": 14.81764705882353, "ID": 6}, {"State": "Alaska", "Year": 2008, "Data_Value": 18.241176470588236, "ID": 7}, {"State": "Alaska", "Year": 2010, "Data_Value": 17.908823529411762, "ID": 8}, {"State": "Alaska", "Year": 2012, "Data_Value": 18.052941176470586, "ID": 9}, {"State": "Alaska", "Year": 2014, "Data_Value": 16.75294117647059, "ID": 10}, {"State": "Alaska", "Year": 2016, "Data_Value": 17.358823529411765, "ID": 11}, {"State": "Alaska", "Year": 2018, "Data_Value": 16.84705882352941, "ID": 12}, {"State": "Alaska", "Year": 2020, "Data_Value": 16.929411764705883, "ID": 13}, {"State": "Arizona", "Year": 2008, "Data_Value": 15.608823529411765, "ID": 14}, {"State": "Arizona", "Year": 2010, "Data_Value": 15.105882352941178, "ID": 15}, {"State": "Arizona", "Year": 2012, "Data_Value": 14.588235294117647, "ID": 16}, {"State": "Arizona", "Year": 2014, "Data_Value": 13.320588235294117, "ID": 17}, {"State": "Arizona", "Year": 2016, "Data_Value": 13.058823529411764, "ID": 18}, {"State": "Arizona", "Year": 2018, "Data_Value": 13.282352941176471, "ID": 19}, {"State": "Arizona", "Year": 2020, "Data_Value": 13.26764705882353, "ID": 20}, {"State": "Arkansas", "Year": 2008, "Data_Value": 12.805882352941175, "ID": 21}, {"State": "Arkansas", "Year": 2010, "Data_Value": 14.50294117647059, "ID": 22}, {"State": "Arkansas", "Year": 2012, "Data_Value": 13.611764705882353, "ID": 23}, {"State": "Arkansas", "Year": 2014, "Data_Value": 13.264705882352942, "ID": 24}, {"State": "Arkansas", "Year": 2016, "Data_Value": 12.873529411764705, "ID": 25}, {"State": "Arkansas", "Year": 2018, "Data_Value": 13.01764705882353, "ID": 26}, {"State": "Arkansas", "Year": 2020, "Data_Value": 13.282352941176471, "ID": 27}, {"State": "California", "Year": 2008, "Data_Value": 16.358823529411765, "ID": 28}, {"State": "California", "Year": 2010, "Data_Value": 16.561764705882354, "ID": 29}, {"State": "California", "Year": 2012, "Data_Value": 15.564705882352943, "ID": 30}, {"State": "California", "Year": 2014, "Data_Value": 14.329411764705881, "ID": 31}, {"State": "California", "Year": 2016, "Data_Value": 13.835294117647058, "ID": 32}, {"State": "California", "Year": 2018, "Data_Value": 13.935294117647059, "ID": 33}, {"State": "California", "Year": 2020, "Data_Value": 14.847058823529412, "ID": 34}, {"State": "Colorado", "Year": 2008, "Data_Value": 10.044117647058824, "ID": 35}, {"State": "Colorado", "Year": 2010, "Data_Value": 9.994117647058824, "ID": 36}, {"State": "Colorado", "Year": 2012, "Data_Value": 9.329411764705881, "ID": 37}, {"State": "Colorado", "Year": 2014, "Data_Value": 9.532352941176471, "ID": 38}, {"State": "Colorado", "Year": 2016, "Data_Value": 9.061764705882354, "ID": 39}, {"State": "Colorado", "Year": 2018, "Data_Value": 9.341176470588236, "ID": 40}, {"State": "Colorado", "Year": 2020, "Data_Value": 9.561764705882354, "ID": 41}, {"State": "Connecticut", "Year": 2008, "Data_Value": 14.51764705882353, "ID": 42}, {"State": "Connecticut", "Year": 2010, "Data_Value": 13.697058823529412, "ID": 43}, {"State": "Connecticut", "Year": 2012, "Data_Value": 13.397058823529411, "ID": 44}, {"State": "Connecticut", "Year": 2014, "Data_Value": 12.66764705882353, "ID": 45}, {"State": "Connecticut", "Year": 2016, "Data_Value": 12.287096774193548, "ID": 46}, {"State": "Connecticut", "Year": 2018, "Data_Value": 11.95483870967742, "ID": 47}, {"State": "Connecticut", "Year": 2020, "Data_Value": 12.006451612903225, "ID": 48}, {"State": "Delaware", "Year": 2008, "Data_Value" ...

# %%
with open('state_year_list.json', 'w') as outfile:
    json.dump(state_year_list, outfile)

# %%
state_year_df.to_json('state_year.json', orient='records')
